# %% [markdown]
# #  Visualisation des données `opencovid19-fr` / pays & département
#
# - Ce script utilise les dernières données dispo sur le repo github de [opencovid19-fr/data](https://github.com/opencovid19-fr/data).
# - Initialement, il est utilisé pour avoir une vision rapide et brute des données afin de pouvoir en faire un commentaire rapide retrouvables [ici](https://twitter.com/data_covid) par exemple.
# - Ce script est fourni tel quel pour un usage personnel et non commercial. Le code l'accompagnant n'est pas optimisé ni testé (pour l'instant).
#
#
# *Dernière mise à jour: 2020-04-15.*

# %%
# %run analysis_code_dept.py
# Out:
# /Users/az02588/.virtualenvs/opencovid19/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
view_cumul = True # voir les chiffres cumulés
view_diff = False  # voir les deltas d'un jour sur l'autre
verbose = False

# %%
latest_data = pd.read_csv(data_url)

# %%
print('Les dernières données datent de : {}.'.format(latest_data.date.unique()[-1]))
# Out:
# Les dernières données sont de : 2020-04-14.

# %%
if verbose is True:
    latest_data.head()

# %% [markdown]
# ## Analyse des données opencovid19-fr

# %%
spf_data = latest_data[latest_data.source_nom == 'OpenCOVID19-fr']

if verbose is True:
    spf_data.head()

# %%
print('Il y a {} lignes et {} colonnes pour les données "OpenCOVID19-fr".'.format(
    spf_data.shape[0], spf_data.shape[1]))
# Out:
# Il y a 532 lignes et 18 colonnes pour les données "OpenCOVID19-fr".

# %%
region_data = gen_region_ts(spf_data)

# %%
if verbose is True:
    spf_data.head()

# %%
analysis_france = get_data_france(spf_data)

# %% [markdown]
# ## Visualisations France

# %%
if view_cumul is True:
    get_plot_cumul_france_separate(analysis_france, keys=keys)

# %%
if view_diff is True:
    get_plot_diff_france_separate(analysis_france, keys=keys)

# %%
if view_cumul is True:
    get_plot_cumul_france_merged(analysis_france, keys=keys)

# %%
if view_diff:
    get_plot_diff_france_merged(analysis_france, keys=keys)

# %% [markdown]
# ## Visualisations Régions

# %%
if view_cumul is True:
    get_plot_cumul_multiregions(region_data, keys=keys)

# %%
if view_diff is True:
    get_plot_diff_multiregions(region_data, keys=keys)

# %% [markdown]
# ## Visualisations sur une région précise

# %%
print('Les noms utilisés pour les régions sont: {}'.format('\n\t- '.join(regions.keys())))
# Out:
# Les noms utilisés pour les régions sont: Auvergne-Rhone-Alpes
# 	- Bourgogne-Franche-Comte
# 	- Bretagne
# 	- Centre-Val de Loire
# 	- Corse
# 	- Grand Est
# 	- Hauts-de-France
# 	- Normandie
# 	- Nouvelle-Aquitaine
# 	- Occitanie
# 	- Pays de la Loire
# 	- Provence-Alpes-Cote d'Azur
# 	- Ile-de-France
# 	- Guadeloupe
# 	- Guyane
# 	- La Reunion
# 	- Martinique
# 	- Mayotte

# %%
chosen_region = 'Grand Est'

# %%
get_plot_cumul_region_separate(chosen_region, region_data, keys=keys)
# Out:
# GUADELOUPE / CUMUL

# %%
get_plot_diff_region_separate(chosen_region, region_data, keys=keys)
# Out:
# GUADELOUPE / DIFF

# %%
get_plot_cumul_region_merged(chosen_region, region_data, keys=keys)
# Out:
# GUADELOUPE / CUMUL

# %%
get_plot_diff_region_merged(chosen_region, region_data, keys=keys)
# Out:
# GUADELOUPE / DIFF
